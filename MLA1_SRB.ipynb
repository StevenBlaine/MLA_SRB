# %% [markdown]
# <a href="https://colab.research.google.com/github/StevenBlaine/MLA_SRB/blob/main/MLA1_SRB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning Assignment 1
# Steven Blaine
# <br>CS430-ON
# <br>Machine Learning in the Cloud

# %% [markdown]
# ### **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### **Connect to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### **Read Dataset as Pandas DataFrame**

# %%
df = pd.read_csv('/content/gdrive/MyDrive/CS430/weather_2012.csv')

# %% [markdown]
# ### **Display Sample of Dataset**

# %%
df.head()
# Out:
#        Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# 0  1/1/2012 0:00      -1.8                -3.9           86                4
# 1  1/1/2012 1:00      -1.8                -3.7           87                4
# 2  1/1/2012 2:00      -1.8                -3.4           89                7
# 3  1/1/2012 3:00      -1.5                -3.2           88                6
# 4  1/1/2012 4:00      -1.5                -3.3           88                7
#
#    Visibility (km)  Stn Press (kPa)               Weather
# 0              8.0           101.24                   Fog
# 1              8.0           101.24                   Fog
# 2              4.0           101.26  Freezing Drizzle,Fog
# 3              4.0           101.27  Freezing Drizzle,Fog
# 4              4.8           101.23                   Fog

# %%
df.tail()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  12/31/2012 19:00       0.1                -2.7           81
# 8780  12/31/2012 20:00       0.2                -2.4           83
# 8781  12/31/2012 21:00      -0.5                -1.5           93
# 8782  12/31/2012 22:00      -0.2                -1.8           89
# 8783  12/31/2012 23:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
df.sample(5)
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 1749  3/13/2012 21:00       1.1                -1.0           86
# 5587  8/20/2012 19:00      20.1                 9.0           49
# 523   1/22/2012 19:00     -10.4               -16.2           62
# 1402  2/28/2012 10:00      -7.5               -13.6           62
# 7971  11/28/2012 3:00      -3.4                -5.9           83
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 1749               20              4.8           100.87       Rain,Fog
# 5587                9             24.1           100.69   Mainly Clear
# 523                19             19.3           102.47  Mostly Cloudy
# 1402               13             24.1           102.65          Clear
# 7971               11             25.0           101.96  Mostly Cloudy

# %% [markdown]
# ### **Display Columns**

# %%
list(df.columns.values)
# Out:
# ['Date/Time',
#  'Temp (C)',
#  'Dew Point Temp (C)',
#  'Rel Hum (%)',
#  'Wind Spd (km/h)',
#  'Visibility (km)',
#  'Stn Press (kPa)',
#  'Weather']

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp (C), Dew Point Temp (C), Rel Hum (%), Wind Spd (km/h), Visibility (km), Stn Press (kPa), Weather]
# Index: []

# %% [markdown]
# ### **Rename Columns**

# %%
df.columns = ['date_time', 'temp_c', 'dew_point', 'relative_humidity', 'wind_speed', 'visibility', 'pressure', 'weather']

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [date_time, temp_c, dew_point, relative_humidity, wind_speed, visibility, pressure, weather]
# Index: []

# %% [markdown]
# ### **Get Statistics**

# %%
df.describe()
# Out:
#             temp_c    dew_point  relative_humidity   wind_speed   visibility  \
# count  8784.000000  8784.000000        8784.000000  8784.000000  8784.000000
# mean      8.798144     2.555294          67.431694    14.945469    27.664447
# std      11.687883    10.883072          16.918881     8.688696    12.622688
# min     -23.300000   -28.500000          18.000000     0.000000     0.200000
# 25%       0.100000    -5.900000          56.000000     9.000000    24.100000
# 50%       9.300000     3.300000          68.000000    13.000000    25.000000
# 75%      18.800000    11.800000          81.000000    20.000000    25.000000
# max      33.000000    24.400000         100.000000    83.000000    48.300000
#
#           pressure
# count  8784.000000
# mean    101.051623
# std       0.844005
# min      97.520000
# 25%     100.560000
# 50%     101.070000
# 75%     101.590000
# max     103.650000

# %% [markdown]
# ### **Add Fahrenheit Column**

# %%
df['temp_f'] = df.apply(lambda x: (9/5)*x['temp_c']+32,axis=1)

# %%
df.head()
# Out:
#        date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0  1/1/2012 0:00    -1.8       -3.9                 86           4
# 1  1/1/2012 1:00    -1.8       -3.7                 87           4
# 2  1/1/2012 2:00    -1.8       -3.4                 89           7
# 3  1/1/2012 3:00    -1.5       -3.2                 88           6
# 4  1/1/2012 4:00    -1.5       -3.3                 88           7
#
#    visibility  pressure               weather  temp_f
# 0         8.0    101.24                   Fog   28.76
# 1         8.0    101.24                   Fog   28.76
# 2         4.0    101.26  Freezing Drizzle,Fog   28.76
# 3         4.0    101.27  Freezing Drizzle,Fog   29.30
# 4         4.8    101.23                   Fog   29.30

# %% [markdown]
# ### **Rearrange Columns**

# %%
df.insert(1, 'temp_f', df.pop('temp_f'))

# %%
df.head()
# Out:
#        date_time  temp_f  temp_c  dew_point  relative_humidity  wind_speed  \
# 0  1/1/2012 0:00   28.76    -1.8       -3.9                 86           4
# 1  1/1/2012 1:00   28.76    -1.8       -3.7                 87           4
# 2  1/1/2012 2:00   28.76    -1.8       -3.4                 89           7
# 3  1/1/2012 3:00   29.30    -1.5       -3.2                 88           6
# 4  1/1/2012 4:00   29.30    -1.5       -3.3                 88           7
#
#    visibility  pressure               weather
# 0         8.0    101.24                   Fog
# 1         8.0    101.24                   Fog
# 2         4.0    101.26  Freezing Drizzle,Fog
# 3         4.0    101.27  Freezing Drizzle,Fog
# 4         4.8    101.23                   Fog

# %% [markdown]
# ### **Change Date-Time Data Type**

# %%
df['date_time']= pd.to_datetime(df['date_time'])

# %%
df.head()
# Out:
#             date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 0 2012-01-01 00:00:00   28.76    -1.8       -3.9                 86
# 1 2012-01-01 01:00:00   28.76    -1.8       -3.7                 87
# 2 2012-01-01 02:00:00   28.76    -1.8       -3.4                 89
# 3 2012-01-01 03:00:00   29.30    -1.5       -3.2                 88
# 4 2012-01-01 04:00:00   29.30    -1.5       -3.3                 88
#
#    wind_speed  visibility  pressure               weather
# 0           4         8.0    101.24                   Fog
# 1           4         8.0    101.24                   Fog
# 2           7         4.0    101.26  Freezing Drizzle,Fog
# 3           6         4.0    101.27  Freezing Drizzle,Fog
# 4           7         4.8    101.23                   Fog

# %% [markdown]
# ### **Create Monthly Average Temp DataFrame**

# %%
df.date_time = pd.to_datetime(df.date_time)
df_2 = df.groupby(df.date_time.dt.strftime('%Y-%m')).temp_f.agg(['mean'])

# %%
print(df_2.head)
# Out:
# <bound method NDFrame.head of                 mean
# date_time
# 2012-01    18.731290
# 2012-02    24.395000
# 2012-03    37.618226
# 2012-04    44.616750
# 2012-05    61.227984
# 2012-06    68.241250
# 2012-07    73.022097
# 2012-08    72.102742
# 2012-09    61.672000
# 2012-10    51.718952
# 2012-11    33.676500
# 2012-12    26.048629>

# %% [markdown]
# ### **Create Scatterplot**

# %%
ax = df.plot(kind='scatter', x = 'temp_f', y = 'relative_humidity', title = "Temperature vs. Relative Humidity", s = 11, c = 'green', figsize = [20,10])
ax.set(xlabel="Temperature (F)", ylabel="Relative Humidity")
# Out:
# [Text(0, 0.5, 'Relative Humidity'), Text(0.5, 0, 'Temperature (F)')]

# %% [markdown]
# ### **Create Lineplot**

# %%
ax = df_2.plot(title = "Average Temperature per Month", c = 'red', figsize = [20,10])
ax.set(xlabel="Month", ylabel="Temperature (F)")
# Out:
# [Text(0, 0.5, 'Temperature (F)'), Text(0.5, 0, 'Month')]

# %% [markdown]
# ### **Create Boxplot**

# %%
df.boxplot(column =['temp_f', 'temp_c', 'dew_point', 'relative_humidity',	'wind_speed',	'visibility',	'pressure'], figsize = [20,10], grid = False)
